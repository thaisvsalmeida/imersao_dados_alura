# %% [markdown]
# <a href="https://colab.research.google.com/github/thaisvsalmeida/imersao_dados_alura/blob/main/ImersaoDados_aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **AULA 2**

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados[["Valor", "Bairro"]]
# Out:
#                                       Valor              Bairro
# 0                              R$ 7.000.000   Planalto Paulista
# 1                              R$ 3.700.000  Jardim dos Estados
# 2                                R$ 380.000     Jardim Reimberg
# 3                                R$ 685.000      Jardim Morumbi
# 4                                R$ 540.000               Mooca
# ...                                     ...                 ...
# 10003                            R$ 665.000          Vila Sofia
# 10004                          R$ 2.300.000     Bosque da Saúde
# 10005                          R$ 1.050.000       Vila da Saúde
# 10006  R$ 2.200\n                      /Mês       Vila Oratório
# 10007                            R$ 270.000         Vila Alpina
#
# [10008 rows x 2 columns]

# %%
dados["Valor"][0]
# Out:
# 'R$ 7.000.000'

# %%
dados["Valor"][0].split()
# Out:
# ['R$', '7.000.000']

# %%
dados["Valor"].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %% [markdown]
# Verifica se a string da coluna 0 é sempre R$

# %%
dados["Valor"].str.split(expand = True)[0].unique()
# Out:
# array(['R$'], dtype=object)

# %%
dados["Valor"].str.split(expand = True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %% [markdown]
# Valores diferentes no array

# %%
len(dados["Valor"].str.split(expand = True)[1].unique())
# Out:
# 1038

# %%
dados[["Moeda", "ValorAnuncio", "Tipo"]] = dados["Valor"].str.split(expand = True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda ValorAnuncio  Tipo
# 0        4          8      6  R$ 7.000.000    R$    7.000.000  None
# 1        4          4      4  R$ 3.700.000    R$    3.700.000  None
# 2        4          3      2    R$ 380.000    R$      380.000  None
# 3        3          2      4    R$ 685.000    R$      685.000  None
# 4        3          2      2    R$ 540.000    R$      540.000  None

# %% [markdown]
# Mostrar apenas os dados em que a coluna Tipo é nula

# %%
dadosFiltrados = dados[dados.Tipo.isnull()]
dadosFiltrados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda ValorAnuncio  \
# ...

# %%
dadosFiltrados["Tipo"].unique()
# Out:
# array([None], dtype=object)

# %%
dadosFiltrados.ValorAnuncio.str.replace(".","").astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0       7000000.00
# 1       3700000.00
# 2        380000.00
# 3        685000.00
# 4        540000.00
#            ...
# 10002   1500000.00
# 10003    665000.00
# 10004   2300000.00
# 10005   1050000.00
# 10007    270000.00
# Name: ValorAnuncio, Length: 9156, dtype: float64

# %%
dadosFiltrados["ValorAnuncioFloat"] = dadosFiltrados.ValorAnuncio.str.replace(".","").astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dadosFiltrados.ValorAnuncioFloat.plot.hist(bins = 50)

# %%
pd.set_option("display.float_format", lambda x: '%.2f' % x)
dadosFiltrados.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  ValorAnuncioFloat
# count   9156.00  9156.00    9156.00 9156.00            9156.00
# mean     434.42     3.45       3.80    3.96         3052202.96
# std     7856.42     1.05       1.97    2.60         3944208.19
# min       10.00     1.00       1.00    1.00           13000.00
# 25%      168.00     3.00       2.00    2.00          890000.00
# 50%      276.00     3.00       4.00    4.00         1800000.00
# 75%      450.00     4.00       5.00    5.00         3500000.00
# max   750000.00    16.00      40.00   50.00        65000000.00

# %%
dadosFiltrados[["Rua", "Bairro", "Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %% [markdown]
# ####Gráfico:
# ####Valor do Anuncio em Milhões de Reais X Quantidade de Imóveis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize =(16, 8))
ax = sns.histplot(data = dadosFiltrados, x = "ValorAnuncioFloat", kde = True, color="purple", lw = 1)
ax.lines[0].set_color("red")
ax.set_title("Imóveis em São Paulo", size=20)
ax.set(xlabel='Valor do Anuncio em Milhões de Reais', ylabel='Quantidade de Imóveis')
plt.xlim((-50, 10000000))
ticks = ax.get_xticks()*10**-6
ax.set_xticklabels(ticks)
plt.show()

# %% [markdown]
# ####Preço do metro quadrado por bairro

# %%
dadosBairros = dadosFiltrados.groupby("Bairro").sum().reset_index()
dadosBairros["R$/m²"] = (dadosBairros["ValorAnuncioFloat"] / dadosBairros["Metragem"])
dadosBairros
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 0            Aclimação     19447      258        240    230
# 1    Alto da Boa Vista      3351       33         41     37
# 2         Alto da Lapa     23940      252        308    320
# 3        Alto da Mooca      5401       66         52     73
# 4    Alto de Pinheiros    158616     1453       1782   1827
# ..                 ...       ...      ...        ...    ...
# 692    Vila Água Funda       761       13         11     13
# 693        Água Branca      2083       37         39     27
# 694          Água Fria      1985       34         41     30
# 695         Água Funda       278        6          5      4
# 696          Água Rasa      1117       16         12     22
#
#      ValorAnuncioFloat    R$/m²
# 0         139292801.00  7162.69
# 1          19130000.00  5708.74
# 2         166653500.00  6961.30
# 3          23683400.00  4385.00
# 4        1764815915.00 11126.34
# ..                 ...      ...
# ...

# %%
plt.figure(figsize =(16, 8))
ax = sns.barplot(data = dadosBairros.head(20), y = "Bairro", x = "R$/m²", lw = 1)
ax.set_title("Imóveis em São Paulo", size=20)
ax.set(xlabel='Preço (R$ / m²)', ylabel='Bairros')
plt.show()

# %% [markdown]
# ###Visualização para analisar quartis, mediana e outliers

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(data = dadosBairros, y = "R$/m²", color = "orange")
ax.set_title("Boxplot de Imóveis em São Paulo", size=20)
plt.ylim((-50, 12000))
plt.show()

# %%
#Top 10 de bairros que aparecem mais vezes no DataFrame
top_bairros = dadosFiltrados["Bairro"].value_counts().head(10).index
top_bairros
# Out:
# Index(['Alto de Pinheiros', 'Jardim Guedala', 'Jardim Paulista',
#        'Brooklin Paulista', 'Jardim Europa', 'Pacaembu', 'Vila Madalena',
#        'Cidade Jardim', 'Planalto Paulista', 'Jardim Leonor'],
#       dtype='object')

# %%
plt.figure(figsize=(10,8))
preco_medio_imovel = dadosFiltrados.ValorAnuncioFloat / dadosFiltrados.Metragem
ax = sns.boxplot(data = dadosFiltrados.query('Bairro in @top_bairros'), x='Bairro', y=preco_medio_imovel)
ax.set_title("Boxplot de Imóveis por Bairro em São Paulo", size=20)
ax.set(xlabel="Bairros", ylabel="Preço do m² por imóvel")
ax.tick_params(axis='x', rotation=45)
plt.show()
